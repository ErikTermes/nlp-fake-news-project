# %% [markdown]
# # Environment

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # Preparing Washington Post & Breitbart datasets

# %%
breitbart = pd.read_csv('data/articles1.csv')
washington_post = pd.read_csv('data/articles3.csv')

# %%
breitbart
# Out:
#        Unnamed: 0     id                                              title  \
# 0               0  17283  House Republicans Fret About Winning Their Hea...
# 1               1  17284  Rift Between Officers and Residents as Killing...
# 2               2  17285  Tyrus Wong, ‘Bambi’ Artist Thwarted by Racial ...
# 3               3  17286  Among Deaths in 2016, a Heavy Toll in Pop Musi...
# 4               4  17287  Kim Jong-un Says North Korea Is Preparing to T...
# ...           ...    ...                                                ...
# 49995       53287  73465   Rex Tillerson Says Climate Change Is Real, but …
# 49996       53288  73466  The Biggest Intelligence Questions Raised by t...
# 49997       53289  73467  Trump Announces Plan That Does Little to Resol...
# 49998       53290  73468    Dozens of For-Profit Colleges Could Soon Close
# 49999       53291  73469                       The Milky Way’s Stolen Stars
#
# ...

# %%
breitbart['publication'].value_counts()
# Out:
# Breitbart           23781
# CNN                 11488
# New York Times       7803
# Business Insider     6757
# Atlantic              171
# Name: publication, dtype: int64

# %%
breitbart = breitbart.loc[breitbart['publication'] == 'Breitbart']

# %%
breitbart
# Out:
#        Unnamed: 0     id                                              title  \
# 7803         7803  26539  CNN’s Zeleny: ’Hard to Imagine’ Obama Would Ha...
# 7804         7804  26540  American Students on Spring Break Chant ’Build...
# 7805         7805  26541  Surge in ’Honour Crimes’ and Forced Marriages ...
# 7806         7806  26542       MILO Announces New Media Venture - Breitbart
# 7807         7807  26543  Jared Kushner at Center of Media Spotlight on ...
# ...           ...    ...                                                ...
# 31579       31587  50353  Tim Kaine Calls State Borders ’Just a Dotted L...
# 31580       31588  50354  Carly Fiorina: Bashes Establishment for Expres...
# 31581       31589  50355  Florida Senate Candidate Drops Out, Opening Sp...
# 31582       31590  50356         Constitution Allows Muslim Immigration Ban
# 31583       31591  50357  Turkey Will ’Open Gates’ to Migrants if EU Mem...
#
# ...

# %%
breitbart_news = breitbart.sample(10000)

# %%
breitbart_news
# Out:
#        Unnamed: 0     id                                              title  \
# 15364       15365  34101  Schumer: Trump’s Border Wall Won’t ’Get the Vo...
# 11311       11311  30047  Levin: Trump’s Comments on Health Care Bill Fa...
# 24083       24087  42838  Dem Rep Grijalva: If Clinton Foundation Is ’Ex...
# 18486       18488  37229  Donald Trump: Candidates Called, Want to Join ...
# 11495       11495  30231  New York Times Sides with Leftist Mob at Everg...
# ...           ...    ...                                                ...
# 16719       16720  35457  Benghazi Security Officer Warned U.S. Months B...
# 12388       12389  31125  Talent Agency WME-IMG Forming PAC for Trump Er...
# 19718       19720  38464  Diana West: Brent Bozell’s Brave New World — ’...
# 24036       24040  42791  Gavin Newsom Calls Transgender Gun Activist ’D...
# 29984       29992  48757  Report: In Midst of Layoffs, CNN Star Gets $10...
#
# ...

# %%
breitbart_news = breitbart_news.drop(['Unnamed: 0'], axis=1)

# %%
breitbart_news = breitbart_news.reset_index().drop(columns=['index'])

# %%
breitbart_news = breitbart_news.drop(columns=['id'])

# %%
breitbart_news
# Out:
#                                                   title publication  \
# 0     Schumer: Trump’s Border Wall Won’t ’Get the Vo...   Breitbart
# 1     Levin: Trump’s Comments on Health Care Bill Fa...   Breitbart
# 2     Dem Rep Grijalva: If Clinton Foundation Is ’Ex...   Breitbart
# 3     Donald Trump: Candidates Called, Want to Join ...   Breitbart
# 4     New York Times Sides with Leftist Mob at Everg...   Breitbart
# ...                                                 ...         ...
# 9995  Benghazi Security Officer Warned U.S. Months B...   Breitbart
# 9996  Talent Agency WME-IMG Forming PAC for Trump Er...   Breitbart
# 9997  Diana West: Brent Bozell’s Brave New World — ’...   Breitbart
# 9998  Gavin Newsom Calls Transgender Gun Activist ’D...   Breitbart
# 9999  Report: In Midst of Layoffs, CNN Star Gets $10...   Breitbart
#
#               author        date    year  month  url  \
# 0            Pam Key  2017-03-26  2017.0    3.0  NaN
# ...

# %%
washington_post
# Out:
#        Unnamed: 0      id                                              title  \
# 0          103459  151908  Alton Sterling’s son: ’Everyone needs to prote...
# 1          103460  151909  Shakespeare’s first four folios sell at auctio...
# 2          103461  151910  My grandmother’s death saved me from a life of...
# 3          103462  151911  I feared my life lacked meaning. Cancer pushed...
# 4          103463  151912  Texas man serving life sentence innocent of do...
# ...           ...     ...                                                ...
# 42566      146028  218078  An eavesdropping Uber driver saved his 16-year...
# 42567      146029  218079  Plane carrying six people returning from a Cav...
# 42568      146030  218080  After helping a fraction of homeowners expecte...
# 42569      146031  218081  Yes, this is real: Michigan just banned bannin...
# 42570      146032  218082  What happened in Washington state after voters...
#
# ...

# %%
washington_post['publication'].value_counts()
# Out:
# NPR                11992
# Washington Post    11114
# Reuters            10710
# Vox                 4947
# Guardian            3808
# Name: publication, dtype: int64

# %%
washington_post = washington_post.loc[washington_post['publication'] == 'Washington Post']

# %%
washington_post
# Out:
#        Unnamed: 0      id                                              title  \
# 31457      134919  204033  Inside the economic war against the Islamic State
# 31458      134920  204034  Putin won 2016, but Russia has its limits as a...
# 31459      134921  204035  Trump and Putin: A relationship where mutual a...
# 31460      134922  204036  Russian operation hacked a Vermont utility, sh...
# 31461      134923  204037  Trump’s victory was history rhyming with itsel...
# ...           ...     ...                                                ...
# 42566      146028  218078  An eavesdropping Uber driver saved his 16-year...
# 42567      146029  218079  Plane carrying six people returning from a Cav...
# 42568      146030  218080  After helping a fraction of homeowners expecte...
# 42569      146031  218081  Yes, this is real: Michigan just banned bannin...
# 42570      146032  218082  What happened in Washington state after voters...
#
# ...

# %%
washington_post = washington_post.sample(10000)

# %%
washington_post = washington_post.drop(['Unnamed: 0'], axis=1)

# %%
washington_post = washington_post.reset_index().drop(columns=['index'])

# %%
washington_post_news = washington_post.drop(columns=['id'])

# %%
washington_post_news
# Out:
#                                                   title      publication  \
# 0     She came to Cleveland uncertain about Trump. S...  Washington Post
# 1     Mission creep doesn’t benefit patients at the ...  Washington Post
# 2     Putin’s ex-wife returns to the spotlight with ...  Washington Post
# 3     In Cleveland, sports prosperity is almost too ...  Washington Post
# 4     ‘Affluenza’ teen flown back to U.S., turned ov...  Washington Post
# ...                                                 ...              ...
# 9995  Baylor refuses to respond to reports of Presid...  Washington Post
# 9996  The four cryptic words Donald Trump can’t stop...  Washington Post
# 9997  Mystery of the spike in deaths between Christm...  Washington Post
# 9998  Good-golly Gorsuch may turn out to be a rascal...  Washington Post
# 9999  Clinton has several VP options: Fiery liberals...  Washington Post
#
#                   author        date    year  month  \
# ...

# %%
breitbart_news.to_csv('breitbart dataset')

# %%
washington_post_news.to_csv('washington post dataset')
